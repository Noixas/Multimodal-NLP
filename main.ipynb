# %% [markdown]
# # Main Notebook
# Make sure you are in a new conda environment with the right python version (3.7.5).   You can create an environment with ` conda create --name="test_nlp2" python=3.7.5`
# You should be able to run this Notebook and replicate results.

# %%
# !pip install -r requirements.txt
# Out:
# Collecting absl-py==0.10.0
#   Using cached absl_py-0.10.0-py3-none-any.whl (127 kB)
# Collecting aiohttp==3.6.2
#   Using cached aiohttp-3.6.2-cp37-cp37m-manylinux1_x86_64.whl (1.2 MB)
# Collecting argon2-cffi==20.1.0
#   Using cached argon2_cffi-20.1.0-cp35-abi3-manylinux1_x86_64.whl (97 kB)
# Collecting async-generator==1.10
#   Using cached async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting async-timeout==3.0.1
#   Using cached async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting attrs==20.2.0
#   Using cached attrs-20.2.0-py2.py3-none-any.whl (48 kB)
# Collecting backcall==0.2.0
#   Using cached backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting beautifulsoup4==4.9.2
#   Using cached beautifulsoup4-4.9.2-py3-none-any.whl (115 kB)
# Collecting bleach==3.2.1
#   Using cached bleach-3.2.1-py2.py3-none-any.whl (145 kB)
# Collecting boto3==1.15.6
#   Using cached boto3-1.15.6-py2.py3-none-any.whl (129 kB)
# Collecting botocore==1.18.6
#   Using cached botocore-1.18.6-py2.py3-none-any.whl (6.6 MB)
# Collecting cachetools==4.1.1
#   Using cached cachetools-4.1.1-py3-none-any.whl (10 kB)
# Collecting certifi==2020.6.20
#   Using cached certifi-2020.6.20-py2.py3-none-any.whl (156 kB)
# Collecting cffi==1.14.3
#   Using cached cffi-1.14.3-cp37-cp37m-manylinux1_x86_64.whl (401 kB)
# Collecting chardet==3.0.4
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting click==7.1.2
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting cycler==0.10.0
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting dbfread==2.0.4
#   Using cached dbfread-2.0.4-py2.py3-none-any.whl (19 kB)
# Collecting deap==1.3.1
#   Using cached deap-1.3.1-cp37-cp37m-manylinux2010_x86_64.whl (157 kB)
# Collecting decorator==4.4.2
#   Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting defusedxml==0.6.0
#   Using cached defusedxml-0.6.0-py2.py3-none-any.whl (23 kB)
# Collecting demjson==2.2.4
#   Using cached demjson-2.2.4-py3-none-any.whl
# Collecting editdistance==0.5.3
#   Using cached editdistance-0.5.3-cp37-cp37m-manylinux1_x86_64.whl (179 kB)
# Collecting entrypoints==0.3
#   Using cached entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting fasttext==0.9.1
#   Using cached fasttext-0.9.1-cp37-cp37m-linux_x86_64.whl
# Collecting filelock==3.0.12
#   Using cached filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Collecting future==0.18.2
#   Using cached future-0.18.2-py3-none-any.whl
# Collecting gdown==3.12.2
#   Using cached gdown-3.12.2-py3-none-any.whl
# Collecting gitdb==4.0.5
#   Using cached gitdb-4.0.5-py3-none-any.whl (63 kB)
# Collecting GitPython==3.1.0
#   Using cached GitPython-3.1.0-py3-none-any.whl (450 kB)
# Collecting google-auth==1.22.0
#   Using cached google_auth-1.22.0-py2.py3-none-any.whl (114 kB)
# Collecting google-auth-oauthlib==0.4.1
#   Using cached google_auth_oauthlib-0.4.1-py2.py3-none-any.whl (18 kB)
# Collecting grpcio==1.32.0
#   Using cached grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl (3.8 MB)
# Collecting idna==2.10
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting ijson==2.6.1
#   Using cached ijson-2.6.1-cp37-cp37m-manylinux1_x86_64.whl (65 kB)
# Collecting importlib-metadata==2.0.0
#   Using cached importlib_metadata-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting ipykernel==5.3.4
#   Using cached ipykernel-5.3.4-py3-none-any.whl (120 kB)
# Collecting ipython-genutils==0.2.0
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting ipywidgets==7.5.1
#   Using cached ipywidgets-7.5.1-py2.py3-none-any.whl (121 kB)
# Collecting jedi==0.17.2
#   Using cached jedi-0.17.2-py2.py3-none-any.whl (1.4 MB)
# Collecting Jinja2==2.11.2
#   Using cached Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting jmespath==0.10.0
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting joblib==0.16.0
#   Using cached joblib-0.16.0-py3-none-any.whl (300 kB)
# Collecting jsonschema==3.2.0
#   Using cached jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Collecting jupyter-client==6.1.7
#   Using cached jupyter_client-6.1.7-py3-none-any.whl (108 kB)
# Collecting jupyter-core==4.6.3
#   Using cached jupyter_core-4.6.3-py2.py3-none-any.whl (83 kB)
# Collecting jupyterlab-pygments==0.1.2
#   Using cached jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting kiwisolver==1.2.0
#   Using cached kiwisolver-1.2.0-cp37-cp37m-manylinux1_x86_64.whl (88 kB)
# Collecting lmdb==0.98
#   Using cached lmdb-0.98-cp37-cp37m-linux_x86_64.whl
# Collecting Markdown==3.2.2
#   Using cached Markdown-3.2.2-py3-none-any.whl (88 kB)
# Collecting MarkupSafe==1.1.1
#   Using cached MarkupSafe-1.1.1-cp37-cp37m-manylinux2010_x86_64.whl (33 kB)
# Collecting matplotlib==3.3.2
#   Using cached matplotlib-3.3.2-cp37-cp37m-manylinux1_x86_64.whl (11.6 MB)
# Collecting mdbtools==0.3.14
#   Using cached mdbtools-0.3.14-py3-none-any.whl
# Collecting meza==0.42.5
#   Using cached meza-0.42.5-py2.py3-none-any.whl (55 kB)
# Collecting mistune==0.8.4
#   Using cached mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting multidict==4.7.6
#   Using cached multidict-4.7.6-cp37-cp37m-manylinux1_x86_64.whl (149 kB)
# Collecting nbclient==0.5.0
#   Using cached nbclient-0.5.0-py3-none-any.whl (65 kB)
# Collecting nbconvert==6.0.7
#   Using cached nbconvert-6.0.7-py3-none-any.whl (552 kB)
# Collecting nbformat==5.0.7
#   Using cached nbformat-5.0.7-py3-none-any.whl (170 kB)
# Collecting nest-asyncio==1.4.1
#   Using cached nest_asyncio-1.4.1-py3-none-any.whl (5.2 kB)
# Collecting nltk==3.4.5
#   Using cached nltk-3.4.5-py3-none-any.whl
# Collecting notebook==6.1.4
#   Using cached notebook-6.1.4-py3-none-any.whl (9.5 MB)
# Collecting numpy==1.19.2
#   Using cached numpy-1.19.2-cp37-cp37m-manylinux2010_x86_64.whl (14.5 MB)
# Collecting oauthlib==3.1.0
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting omegaconf==2.0.1rc4
#   Using cached omegaconf-2.0.1rc4-py3-none-any.whl (34 kB)
# Collecting packaging==20.4
#   Using cached packaging-20.4-py2.py3-none-any.whl (37 kB)
# Collecting pandas==1.1.2
#   Using cached pandas-1.1.2-cp37-cp37m-manylinux1_x86_64.whl (10.5 MB)
# Collecting pandocfilters==1.4.2
#   Using cached pandocfilters-1.4.2-py3-none-any.whl
# Collecting parso==0.7.1
#   Using cached parso-0.7.1-py2.py3-none-any.whl (109 kB)
# Collecting pexpect==4.8.0
#   Using cached pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
# Collecting pickleshare==0.7.5
#   Using cached pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting Pillow==7.2.0
#   Using cached Pillow-7.2.0-cp37-cp37m-manylinux1_x86_64.whl (2.2 MB)
# Collecting prometheus-client==0.8.0
#   Using cached prometheus_client-0.8.0-py2.py3-none-any.whl (53 kB)
# Collecting prompt-toolkit==3.0.7
#   Using cached prompt_toolkit-3.0.7-py3-none-any.whl (355 kB)
# Collecting protobuf==3.13.0
#   Using cached protobuf-3.13.0-cp37-cp37m-manylinux1_x86_64.whl (1.3 MB)
# Collecting ptyprocess==0.6.0
#   Using cached ptyprocess-0.6.0-py2.py3-none-any.whl (39 kB)
# Collecting pyasn1==0.4.8
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting pyasn1-modules==0.2.8
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting pybind11==2.5.0
#   Using cached pybind11-2.5.0-py2.py3-none-any.whl (296 kB)
# Collecting pycparser==2.20
#   Using cached pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting Pygments==2.7.1
#   Using cached Pygments-2.7.1-py3-none-any.whl (944 kB)
# Collecting pygogo==0.13.2
#   Using cached pygogo-0.13.2-py2.py3-none-any.whl (20 kB)
# Collecting pymongo==3.11.0
#   Using cached pymongo-3.11.0-cp37-cp37m-manylinux2014_x86_64.whl (511 kB)
# Collecting pyparsing==2.4.7
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting pyrsistent==0.17.3
#   Using cached pyrsistent-0.17.3-cp37-cp37m-linux_x86_64.whl
# Collecting PySocks==1.7.1
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting python-dateutil==2.8.1
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting python-slugify==1.2.6
#   Using cached python_slugify-1.2.6-py2.py3-none-any.whl
# Collecting pytz==2020.1
#   Using cached pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Collecting PyYAML==5.3.1
#   Using cached PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl
# Collecting pyzmq==19.0.2
#   Using cached pyzmq-19.0.2-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
# Collecting regex==2020.9.27
#   Using cached regex-2020.9.27-cp37-cp37m-manylinux2010_x86_64.whl (662 kB)
# Collecting requests==2.23.0
#   Using cached requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting requests-oauthlib==1.3.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting rsa==4.6
#   Using cached rsa-4.6-py3-none-any.whl (47 kB)
# Collecting s3transfer==0.3.3
#   Using cached s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
# Collecting sacremoses==0.0.43
#   Using cached sacremoses-0.0.43-py3-none-any.whl
# Collecting scikit-learn==0.23.2
#   Using cached scikit_learn-0.23.2-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
# Collecting scipy==1.5.2
#   Using cached scipy-1.5.2-cp37-cp37m-manylinux1_x86_64.whl (25.9 MB)
# Collecting seaborn==0.11.0
#   Using cached seaborn-0.11.0-py3-none-any.whl (283 kB)
# Collecting Send2Trash==1.5.0
#   Using cached Send2Trash-1.5.0-py3-none-any.whl (12 kB)
# Collecting sentencepiece==0.1.91
#   Using cached sentencepiece-0.1.91-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
# Collecting six==1.15.0
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting sklearn==0.0
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# Collecting smmap==3.0.4
#   Using cached smmap-3.0.4-py2.py3-none-any.whl (25 kB)
# Collecting soupsieve==2.0.1
#   Using cached soupsieve-2.0.1-py3-none-any.whl (32 kB)
# Collecting tensorboard==2.3.0
#   Using cached tensorboard-2.3.0-py3-none-any.whl (6.8 MB)
# Collecting tensorboard-plugin-wit==1.7.0
#   Using cached tensorboard_plugin_wit-1.7.0-py3-none-any.whl (779 kB)
# Collecting termcolor==1.1.0
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Collecting terminado==0.9.1
#   Using cached terminado-0.9.1-py3-none-any.whl (13 kB)
# Collecting testpath==0.4.4
#   Using cached testpath-0.4.4-py2.py3-none-any.whl (163 kB)
# Collecting threadpoolctl==2.1.0
#   Using cached threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting tokenizers==0.8.1rc2
#   Using cached tokenizers-0.8.1rc2-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
# Collecting toolz==0.11.1
#   Using cached toolz-0.11.1-py3-none-any.whl (55 kB)
# Collecting torchtext==0.5.0
#   Using cached torchtext-0.5.0-py3-none-any.whl (73 kB)
# Collecting tornado==6.0.4
#   Using cached tornado-6.0.4-cp37-cp37m-linux_x86_64.whl
# Collecting tqdm==4.50.0
#   Using cached tqdm-4.50.0-py2.py3-none-any.whl (70 kB)
# Collecting transformers==3.2.0
#   Using cached transformers-3.2.0-py3-none-any.whl (1.0 MB)
# Collecting typing-extensions==3.7.4.3
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting Unidecode==1.1.1
#   Using cached Unidecode-1.1.1-py2.py3-none-any.whl (238 kB)
# Collecting urllib3==1.25.10
#   Using cached urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# Collecting wcwidth==0.2.5
#   Using cached wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting webencodings==0.5.1
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting Werkzeug==1.0.1
#   Using cached Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting widgetsnbextension==3.5.1
#   Using cached widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
# Collecting xlrd==1.2.0
#   Using cached xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
# Collecting yarl==1.6.0
#   Using cached yarl-1.6.0-cp37-cp37m-manylinux1_x86_64.whl (258 kB)
# Collecting zipp==3.2.0
#   Using cached zipp-3.2.0-py3-none-any.whl (5.1 kB)
# Collecting wandb==0.10.19
#   Using cached wandb-0.10.19-py2.py3-none-any.whl (2.0 MB)
# Requirement already satisfied: setuptools>=0.7.0 in /home/astro/anaconda3/envs/test_nlp2_1/lib/python3.7/site-packages (from fasttext==0.9.1->-r requirements.txt (line 25)) (52.0.0.post20210125)
# Collecting requests[socks]
#   Using cached requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting traitlets>=4.1.0
#   Using cached traitlets-5.0.5-py3-none-any.whl (100 kB)
# Collecting ipython>=5.0.0
#   Using cached ipython-7.21.0-py3-none-any.whl (784 kB)
# Requirement already satisfied: wheel>=0.26 in /home/astro/anaconda3/envs/test_nlp2_1/lib/python3.7/site-packages (from tensorboard==2.3.0->-r requirements.txt (line 107)) (0.36.2)
# Collecting torch
#   Using cached torch-1.7.1-cp37-cp37m-manylinux1_x86_64.whl (776.8 MB)
# Collecting configparser>=3.8.1
#   Using cached configparser-5.0.2-py3-none-any.whl (19 kB)
# Collecting pathtools
#   Using cached pathtools-0.1.2-py3-none-any.whl
# Collecting shortuuid>=0.5.0
#   Using cached shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# Collecting psutil>=5.0.0
#   Using cached psutil-5.8.0-cp37-cp37m-manylinux2010_x86_64.whl (296 kB)
# Collecting subprocess32>=3.5.3
#   Using cached subprocess32-3.5.4-py3-none-any.whl
# Collecting docker-pycreds>=0.4.0
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting sentry-sdk>=0.4.0
#   Using cached sentry_sdk-0.20.3-py2.py3-none-any.whl (131 kB)
# Collecting promise<3,>=2.0
#   Using cached promise-2.3-py3-none-any.whl
# Collecting requests[socks]
#   Using cached requests-2.25.0-py2.py3-none-any.whl (61 kB)
#   Using cached requests-2.24.0-py2.py3-none-any.whl (61 kB)
# WARNING: The candidate selected for download or install is a yanked version: 'omegaconf' candidate (version 2.0.1rc4 at https://files.pythonhosted.org/packages/03/c6/dec84d1b2a3d645f03201dca03bc879b6116cb6503449a31d7ff9c1394a4/omegaconf-2.0.1rc4-py3-none-any.whl#sha256=e04462f7e3d8f51532221471b241f67e35a36a04e364c70987018faadd273cc0 (from https://pypi.org/simple/omegaconf/) (requires-python:>=3.6))
# Reason for being yanked: <none given>
# Installing collected packages: zipp, ipython-genutils, traitlets, six, pyrsistent, importlib-metadata, attrs, wcwidth, tornado, pyzmq, python-dateutil, pyparsing, ptyprocess, parso, jupyter-core, jsonschema, webencodings, typing-extensions, Pygments, pycparser, prompt-toolkit, pickleshare, pexpect, packaging, nest-asyncio, nbformat, multidict, MarkupSafe, jupyter-client, jedi, idna, decorator, backcall, async-generator, yarl, urllib3, testpath, pyasn1, pandocfilters, nbclient, mistune, jupyterlab-pygments, Jinja2, ipython, entrypoints, defusedxml, chardet, cffi, certifi, bleach, async-timeout, terminado, smmap, Send2Trash, rsa, requests, pyasn1-modules, prometheus-client, oauthlib, numpy, nbconvert, jmespath, ipykernel, cachetools, argon2-cffi, aiohttp, Unidecode, tqdm, threadpoolctl, soupsieve, scipy, requests-oauthlib, regex, pytz, PySocks, Pillow, notebook, kiwisolver, joblib, google-auth, gitdb, cycler, click, botocore, xlrd, widgetsnbextension, Werkzeug, torch, tokenizers, tensorboard-plugin-wit, subprocess32, shortuuid, sentry-sdk, sentencepiece, scikit-learn, sacremoses, s3transfer, PyYAML, python-slugify, pymongo, pygogo, pybind11, psutil, protobuf, promise, pathtools, pandas, matplotlib, Markdown, ijson, grpcio, google-auth-oauthlib, GitPython, filelock, docker-pycreds, dbfread, configparser, beautifulsoup4, absl-py, wandb, transformers, torchtext, toolz, termcolor, tensorboard, sklearn, seaborn, omegaconf, nltk, meza, mdbtools, lmdb, ipywidgets, gdown, future, fasttext, editdistance, demjson, deap, boto3
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2020.12.5
#     Uninstalling certifi-2020.12.5:
#       Successfully uninstalled certifi-2020.12.5
# Successfully installed GitPython-3.1.0 Jinja2-2.11.2 Markdown-3.2.2 MarkupSafe-1.1.1 Pillow-7.2.0 PySocks-1.7.1 PyYAML-5.3.1 Pygments-2.7.1 Send2Trash-1.5.0 Unidecode-1.1.1 Werkzeug-1.0.1 absl-py-0.10.0 aiohttp-3.6.2 argon2-cffi-20.1.0 async-generator-1.10 async-timeout-3.0.1 attrs-20.2.0 backcall-0.2.0 beautifulsoup4-4.9.2 bleach-3.2.1 boto3-1.15.6 botocore-1.18.6 cachetools-4.1.1 certifi-2020.6.20 cffi-1.14.3 chardet-3.0.4 click-7.1.2 configparser-5.0.2 cycler-0.10.0 dbfread-2.0.4 deap-1.3.1 decorator-4.4.2 defusedxml-0.6.0 demjson-2.2.4 docker-pycreds-0.4.0 editdistance-0.5.3 entrypoints-0.3 fasttext-0.9.1 filelock-3.0.12 future-0.18.2 gdown-3.12.2 gitdb-4.0.5 google-auth-1.22.0 google-auth-oauthlib-0.4.1 grpcio-1.32.0 idna-2.10 ijson-2.6.1 importlib-metadata-2.0.0 ipykernel-5.3.4 ipython-7.21.0 ipython-genutils-0.2.0 ipywidgets-7.5.1 jedi-0.17.2 jmespath-0.10.0 joblib-0.16.0 jsonschema-3.2.0 jupyter-client-6.1.7 jupyter-core-4.6.3 jupyterlab-pygments-0.1.2 kiwisolver-1.2.0 lmdb-0.98 matplotlib-3.3.2 mdbtools-0.3.14 meza-0.42.5 mistune-0.8.4 multidict-4.7.6 nbclient-0.5.0 nbconvert-6.0.7 nbformat-5.0.7 nest-asyncio-1.4.1 nltk-3.4.5 notebook-6.1.4 numpy-1.19.2 oauthlib-3.1.0 omegaconf-2.0.1rc4 packaging-20.4 pandas-1.1.2 pandocfilters-1.4.2 parso-0.7.1 pathtools-0.1.2 pexpect-4.8.0 pickleshare-0.7.5 prometheus-client-0.8.0 promise-2.3 prompt-toolkit-3.0.7 protobuf-3.13.0 psutil-5.8.0 ptyprocess-0.6.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pybind11-2.5.0 pycparser-2.20 pygogo-0.13.2 pymongo-3.11.0 pyparsing-2.4.7 pyrsistent-0.17.3 python-dateutil-2.8.1 python-slugify-1.2.6 pytz-2020.1 pyzmq-19.0.2 regex-2020.9.27 requests-2.23.0 requests-oauthlib-1.3.0 rsa-4.6 s3transfer-0.3.3 sacremoses-0.0.43 scikit-learn-0.23.2 scipy-1.5.2 seaborn-0.11.0 sentencepiece-0.1.91 sentry-sdk-0.20.3 shortuuid-1.0.1 six-1.15.0 sklearn-0.0 smmap-3.0.4 soupsieve-2.0.1 subprocess32-3.5.4 tensorboard-2.3.0 tensorboard-plugin-wit-1.7.0 termcolor-1.1.0 terminado-0.9.1 testpath-0.4.4 threadpoolctl-2.1.0 tokenizers-0.8.1rc2 toolz-0.11.1 torch-1.7.1 torchtext-0.5.0 tornado-6.0.4 tqdm-4.50.0 traitlets-5.0.5 transformers-3.2.0 typing-extensions-3.7.4.3 urllib3-1.25.10 wandb-0.10.19 wcwidth-0.2.5 webencodings-0.5.1 widgetsnbextension-3.5.1 xlrd-1.2.0 yarl-1.6.0 zipp-3.2.0

# %%
# !conda install pytorch==1.6.0 torchvision==0.7.0 cudatoolkit=10.1 -c pytorch --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/astro/anaconda3/envs/test_nlp2_1
#
#   added / updated specs:
#     - cudatoolkit=10.1
#     - pytorch==1.6.0
#     - torchvision==0.7.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cudatoolkit-10.1.243       |       h6bb024c_0       347.4 MB
#     lz4-c-1.9.3                |       h2531618_0         186 KB
#     mkl-service-2.3.0          |   py37he8ac12f_0          52 KB
#     mkl_fft-1.3.0              |   py37h54f3939_0         167 KB
#     mkl_random-1.1.1           |   py37h0573a6f_0         322 KB
#     ninja-1.10.2               |   py37hff7bd54_0         1.4 MB
#     numpy-1.19.2               |   py37h54aff64_0          22 KB
#     numpy-base-1.19.2          |   py37hfa32c7d_0         4.1 MB
#     olefile-0.46               |           py37_0          50 KB
#     pillow-8.1.0               |   py37he98fc37_0         623 KB
#     pytorch-1.6.0              |py3.7_cuda10.1.243_cudnn7.6.3_0       515.9 MB  pytorch
#     six-1.15.0                 |   py37h06a4308_0          27 KB
#     torchvision-0.7.0          |       py37_cu101        11.0 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:       881.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   cudatoolkit        pkgs/main/linux-64::cudatoolkit-10.1.243-h6bb024c_0
#   freetype           pkgs/main/linux-64::freetype-2.10.4-h5ab3b9f_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2020.2-254
#   jpeg               pkgs/main/linux-64::jpeg-9b-h024ee3a_2
#   lcms2              pkgs/main/linux-64::lcms2-2.11-h396b838_0
#   libpng             pkgs/main/linux-64::libpng-1.6.37-hbc83047_0
#   libtiff            pkgs/main/linux-64::libtiff-4.1.0-h2733197_1
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.3-h2531618_0
#   mkl                pkgs/main/linux-64::mkl-2020.2-256
#   mkl-service        pkgs/main/linux-64::mkl-service-2.3.0-py37he8ac12f_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.0-py37h54f3939_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.1.1-py37h0573a6f_0
#   ninja              pkgs/main/linux-64::ninja-1.10.2-py37hff7bd54_0
#   numpy              pkgs/main/linux-64::numpy-1.19.2-py37h54aff64_0
#   numpy-base         pkgs/main/linux-64::numpy-base-1.19.2-py37hfa32c7d_0
#   olefile            pkgs/main/linux-64::olefile-0.46-py37_0
#   pillow             pkgs/main/linux-64::pillow-8.1.0-py37he98fc37_0
#   pytorch            pytorch/linux-64::pytorch-1.6.0-py3.7_cuda10.1.243_cudnn7.6.3_0
#   six                pkgs/main/linux-64::six-1.15.0-py37h06a4308_0
#   torchvision        pytorch/linux-64::torchvision-0.7.0-py37_cu101
#   zstd               pkgs/main/linux-64::zstd-1.4.5-h9ceee32_0
#
#
#
# Downloading and Extracting Packages
# mkl_random-1.1.1     | 322 KB    | ##################################### | 100%
# ninja-1.10.2         | 1.4 MB    | ##################################### | 100%
# pytorch-1.6.0        | 515.9 MB  | ##################################### | 100%
# numpy-1.19.2         | 22 KB     | ##################################### | 100%
# olefile-0.46         | 50 KB     | ##################################### | 100%
# numpy-base-1.19.2    | 4.1 MB    | ##################################### | 100%
# mkl-service-2.3.0    | 52 KB     | ##################################### | 100%
# cudatoolkit-10.1.243 | 347.4 MB  | ##################################### | 100%
# lz4-c-1.9.3          | 186 KB    | ##################################### | 100%
# pillow-8.1.0         | 623 KB    | ##################################### | 100%
# mkl_fft-1.3.0        | 167 KB    | ##################################### | 100%
# torchvision-0.7.0    | 11.0 MB   | ##################################### | 100%
# six-1.15.0           | 27 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !git clone https://github.com/NVIDIA/apex
# %cd apex
# !pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./
# %cd ..

# %%
# %cd model_checkpoints
# !wget 'https://convaisharables.blob.core.windows.net/uniter/pretrained/uniter-base.pt
import torch
model_name = 'uniter-base.pt'
checkpoint = torch.load(model_name)
state_dict = {'model_state_dict': checkpoint}
torch.save(state_dict, model_name)
# %cd ..

# %%
import tarfile
import gdown

# !mkdir dataset
# %cd dataset
features_name_file = own_features.tar.xz
url = 'https://drive.google.com/uc?id=1vTl31tkkm_kpOsL7f3rhGWQFke2y96g_'
gdown.download(url, features_name_file, quiet=False)
#Untar file
tar = tarfile.open(features_name_file, "r:xz")
tar.extractall()
tar.close()
# Out:
#   File "<ipython-input-6-ad5798f156bc>", line 5
#     gdown --id 1vTl31tkkm_kpOsL7f3rhGWQFke2y96g_ --output features_name_file
#                ^
# SyntaxError: invalid syntax
